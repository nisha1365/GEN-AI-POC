# %% [markdown]
# <a href="https://colab.research.google.com/github/nisha1365/GEN-AI-POC/blob/main/tweet_with_sentiment_label_diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # For Excel File reading and producing:

# %%
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')

# Load the Excel file
file_path = "/content/tweets_by_topics_diabetes_18th_March.xlsx"
xls = pd.ExcelFile(file_path)
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
# Create a function to clean the text

import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

import re
def clean_text(text):
    # Check if text is a string
    if not isinstance(text, str):
        return ''  # Return an empty string or some default value
    # Remove mentions (@)
    text = re.sub(r'@[A-Za-z0-9_]+', '', text)
    # Remove hashtags (#) without removing the word following it
    text = re.sub(r'#(\w+)', r'\1', text)
    # Remove URLs (http/https)
    text = re.sub(r'https?://\S+|www\.\S+|https?\/\/t\.co\/\S+', '', text)
    # Remove emojis
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F" # emoticons
                               u"\U0001F300-\U0001F5FF" # symbols & pictographs
                               u"\U0001F680-\U0001F6FF" # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF" # flags (iOS)
                               u"\U00002500-\U00002BEF" # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f" # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    text = re.sub(emoji_pattern, '', text)
    # Remove extra white spaces
    text = re.sub(r'\s+', ' ', text.strip())
    # Convert text to lowercase
    text = text.lower()

    # Tokenize the text
    tokens = word_tokenize(text)

    # Initialize lemmatizer
    lemmatizer = WordNetLemmatizer()

    # Lemmatize tokens
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]

    # Join tokens back into text
    cleaned_text = ' '.join(lemmatized_tokens)
    return cleaned_text
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Create a sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Create a new Excel writer object
new_file_path = "/content/tweets_with_sentiment_diabetes.xlsx"
writer = pd.ExcelWriter(new_file_path)

# Iterate through each sheet in the Excel file
for sheet_name in xls.sheet_names:
    # Read the sheet into a DataFrame
    df = pd.read_excel(file_path, sheet_name=sheet_name)

    # Add a new column for cleaned text
    df['clean_text'] = df['text'].apply(clean_text)

    # Add a new column for sentiment label
    df['sentiment_label'] = df['clean_text'].apply(lambda x: sid.polarity_scores(x)['compound'])

    # Classify the sentiment based on the compound score
    df['sentiment_label'] = df['sentiment_label'].apply(lambda score: 'positive' if score > 0 else ('negative' if score < 0 else 'neutral'))

    # Save the modified DataFrame to the new Excel file
    df.to_excel(writer, sheet_name=sheet_name, index=False)

# Close the Excel writer
writer.save()

print("Sentiment analysis and data cleaning completed. New file created:", new_file_path)
# Out:
# <ipython-input-3-2adec688ea23>:26: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()
# Sentiment analysis and data cleaning completed. New file created: /content/tweets_with_sentiment_diabetes.xlsx

# %% [markdown]
# # For csv File reading and producing:

# %%
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')

# Load the Excel file
file_path = "/content/cleaned_tweets_38402_4th_March.csv"
df = pd.read_csv(file_path)
df
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
#                                                file_name             tweet_id  \
# 0      search_recent_tweets_Pediatric Vaccines Produc...  1756919733893402830
# 1      search_recent_tweets_Pediatric Vaccines Produc...  1756917317584249241
# 2      search_recent_tweets_Pediatric Vaccines Produc...  1756916557148815863
# 3      search_recent_tweets_Pediatric Vaccines Produc...  1756916318152823004
# 4      search_recent_tweets_Pediatric Vaccines Produc...  1756915179894239733
# ...                                                  ...                  ...
# 38397  search_recent_tweets_Pediatric Vaccines Popula...  1758743150037000224
# 38398  search_recent_tweets_Pediatric Vaccines Popula...  1758743008835752435
# 38399  search_recent_tweets_Pediatric Vaccines Popula...  1758740560796680597
# 38400  search_recent_tweets_Pediatric Vaccines Popula...  1758739242182914204
# 38401  search_recent_tweets_Pediatric Vaccines Popula...  1758735123388715271
#
#                                                     text            author_id  \
# 0      @MaryB4568355642 @FormerAntivax Really? How ma...            253779553
# 1      @InnerDelicious @Jimmywonton2 Neither is tetan...  1244624259315621889
# 2      @AuthorTOBurnett lol it should have come with ...  1624315026374008832
# 3      @AngelSpirit1776 Yea I have a lot of experienc...  1733908529554075648
# 4      I just had a bunch of vaccines done today. Now...            193624874
# ...                                                  ...                  ...
# 38397  Satvik, a 1.5 month old baby boy died followin...   935471466308558848
# 38398  @Debunk_the_Funk Hook in and have mine, Austra...  1506597862301642758
# 38399  David Kimberlin, M.D., co-director of UAB and ...             13265132
# 38400  @DogBananaFunky @MadelineCowan8 @PetousisH Mak...           2532424399
# 38401  correctly classified under crime category\n\nh...   877505926403641344
#
#        conversation_id                 created_at lang referenced_tweets_type  \
# 0         1.756784e+18  2024-02-12T05:54:41+00:00   en             replied_to
# 1         1.756676e+18  2024-02-12T05:45:05+00:00   en             replied_to
# 2         1.756656e+18  2024-02-12T05:42:03+00:00   en             replied_to
# 3         1.756703e+18  2024-02-12T05:41:06+00:00   en             replied_to
# 4                  NaN  2024-02-12T05:36:35+00:00   en                      0
# ...                ...                        ...  ...                    ...
# 38397              NaN  2024-02-17T06:40:17+00:00   en                      0
# 38398     1.758588e+18  2024-02-17T06:39:43+00:00   en             replied_to
# 38399              NaN  2024-02-17T06:30:00+00:00   en                      0
# 38400     1.758615e+18  2024-02-17T06:24:45+00:00   en             replied_to
# 38401              NaN  2024-02-17T06:08:23+00:00   en                      0
#
#        referenced_tweets_id                                     public_metrics
# 0       1756880353191690718  {'retweet_count': 0, 'reply_count': 2, 'like_c...
# 1       1756690613855010835  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 2       1756655895864312067  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 3       1756912176587997541  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 4                         0  {'retweet_count': 0, 'reply_count': 2, 'like_c...
# ...                     ...                                                ...
# 38397                     0  {'retweet_count': 8, 'reply_count': 0, 'like_c...
# 38398   1758587932170916099  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 38399                     0  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 38400   1758737616147730935  {'retweet_count': 0, 'reply_count': 2, 'like_c...
# 38401                     0  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
# [38402 rows x 10 columns]

# %%
# Create a function to clean the text

import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

import re
def clean_text(text):
    # Remove mentions (@)
    text = re.sub(r'@[A-Za-z0-9_]+', '', text)
    # Remove hashtags (#) without removing the word following it
    text = re.sub(r'#(\w+)', r'\1', text)
    # Remove URLs (http/https)
    text = re.sub(r'https?://\S+|www\.\S+|https?\/\/t\.co\/\S+', '', text)
    # Remove emojis
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F" # emoticons
                               u"\U0001F300-\U0001F5FF" # symbols & pictographs
                               u"\U0001F680-\U0001F6FF" # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF" # flags (iOS)
                               u"\U00002500-\U00002BEF" # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f" # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    text = re.sub(emoji_pattern, '', text)
    # Remove extra white spaces
    text = re.sub(r'\s+', ' ', text.strip())
    # Convert text to lowercase
    text = text.lower()

    # Tokenize the text
    tokens = word_tokenize(text)

    # Initialize lemmatizer
    lemmatizer = WordNetLemmatizer()

    # Lemmatize tokens
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]

    # Join tokens back into text
    cleaned_text = ' '.join(lemmatized_tokens)
    return cleaned_text
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Create a sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Create a new Excel writer object
new_file_path = "/content/tweets_with_sentiment_38402.csv"

# Add a new column for cleaned text
df['clean_text'] = df['text'].apply(clean_text)

# Add a new column for sentiment label
df['sentiment_label'] = df['clean_text'].apply(lambda x: sid.polarity_scores(x)['compound'])

# Classify the sentiment based on the compound score
df['sentiment_label'] = df['sentiment_label'].apply(lambda score: 'positive' if score > 0 else ('negative' if score < 0 else 'neutral'))

# Save the modified DataFrame to the new Excel file
df.to_csv(new_file_path, index=False)

# Close the Excel writer

print("Sentiment analysis and data cleaning completed. New file created:", new_file_path)
# Out:
# Sentiment analysis and data cleaning completed. New file created: /content/tweets_with_sentiment_38402.csv

# %%
data = pd.read_csv("/content/tweets_with_sentiment_38402.csv")
data['sentiment_label'].value_counts()
# Out:
# negative    18143
# positive    15158
# neutral      5101
# Name: sentiment_label, dtype: int64
