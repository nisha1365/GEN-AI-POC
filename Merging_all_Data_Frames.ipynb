# %% [markdown]
# <a href="https://colab.research.google.com/github/nisha1365/Sanofi-POC/blob/main/Merging_all_Data_Frames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1st CSV "Tweet hemophilia alldata db 17_08_23".

# %%
import pandas as pd

# %%
df1 = pd.read_csv("/content/tweet_hemophilia_alldata_db_17_08_23.csv")
df1
# Out:
#        Unnamed: 0  tweet_id  external_twitter_id  \
# 0               0   1030258  1684840696631422976
# 1               1   1030186  1684592270652452864
# 2               2   1030263  1684814677086187520
# 3               3   1030274  1684722157685993472
# 4               4   1030288  1684658401794469888
# ...           ...       ...                  ...
# 15461       15461    170058  1623060615991291927
# 15462       15462    170507  1623692536354070529
# 15463       15463    170966  1625648406721880068
# 15464       15464    171494  1628077094440943616
# 15465       15465    172062  1630292933139202050
#
#                                                     text            author_id  \
# 0      3 peaks Challenge #AxioActive💪\n\nOn the 12th ...   905089209446346752
# 1      Roche Drops Hemophilia A Candidate, Prepares f...             76385834
# 2      Roche moves one Spark hemophilia gene therapy ...  1481278019352338433
# ...

# %%
df1.drop(['Unnamed: 0'], axis = 1, inplace = True)
df1.head()
# Out:
#    tweet_id  external_twitter_id  \
# 0   1030258  1684840696631422976
# 1   1030186  1684592270652452864
# 2   1030263  1684814677086187520
# 3   1030274  1684722157685993472
# 4   1030288  1684658401794469888
#
#                                                 text            author_id  \
# 0  3 peaks Challenge #AxioActive💪\n\nOn the 12th ...   905089209446346752
# 1  Roche Drops Hemophilia A Candidate, Prepares f...             76385834
# 2  Roche moves one Spark hemophilia gene therapy ...  1481278019352338433
# 3  On #WorldHepatitisDay we put middle finger up ...  1145266586015502336
# 4  One of our newest internship programs, launche...            211288748
#
#             created_at lang  referenced_tweets_type  referenced_tweets_id  \
# 0  2023-07-28 08:18:19   en                       0                     0
# 1  2023-07-27 15:51:10   en                       0                     0
# 2  2023-07-28 06:34:56   en                       0                     0
# ...

# %%
df1['tweet_id'].nunique()
# Out:
# 15466

# %%
df2 = pd.read_csv("/content/tweet_hemophilia_alldata_db.csv")
df2
# Out:
#        Unnamed: 0             tweet_id  \
# 0               0  1638511061652455425
# 1               1  1638688071012032513
# 2               2  1638851084696563712
# 3               3  1638518390359834624
# 4               4  1638682916212359169
# ...           ...                  ...
# 14332       14332  1683839551645814784
# 14333       14333  1683938283003183104
# 14334       14334  1683861079674195968
# 14335       14335  1683918306082955264
# 14336       14336  1683834001562140672
#
#                                                     text            author_id  \
# 0      They say old age isn't so bad when considering...            303118729
# 1      If by AMD you mean Age-related Macular Degener...             84063737
# 2      🗒️ How can your institution prepare to offer g...             33633067
# 3      Hemophilia is an inherited disorder in which t...  1044251825921241088
# 4      Time for a condemnation\n@wfhemophilia @isth @...           2317618712
# ...

# %%
df2['tweet_id'].nunique()
# Out:
# 14337

# %%
df2.drop(['Unnamed: 0'], axis = 1, inplace = True)
df2.head()
# Out:
#               tweet_id                                               text  \
# 0  1638511061652455425  They say old age isn't so bad when considering...
# 1  1638688071012032513  If by AMD you mean Age-related Macular Degener...
# 2  1638851084696563712  🗒️ How can your institution prepare to offer g...
# 3  1638518390359834624  Hemophilia is an inherited disorder in which t...
# 4  1638682916212359169  Time for a condemnation\n@wfhemophilia @isth @...
#
#              author_id           created_at lang  referenced_tweets_type  \
# 0            303118729  2023-03-22 12:00:53   en                       0
# 1             84063737  2023-03-22 23:44:16   en                       3
# 2             33633067  2023-03-23 10:32:01   en                       0
# 3  1044251825921241088  2023-03-22 12:30:01   en                       0
# 4           2317618712  2023-03-22 23:23:47   en                       3
#
#    referenced_tweets_id infos  association_tweet_id  association_scope_id
# ...

# %%
common_tweetids = set(df1['tweet_id']).intersection(set(df2['tweet_id']))

if common_tweetids:
  print(f"Commontweetids found: {common_tweetids}")

else:
  print("No common tweetids found.")
# Out:
# No common tweetids found.

# %% [markdown]
# No common tweets, so using Concatenation function not merging.

# %%
combined_df = pd.concat([df1,df2], ignore_index=True)
combined_df
# Out:
#                   tweet_id  external_twitter_id  \
# 0                  1030258         1.684841e+18
# 1                  1030186         1.684592e+18
# 2                  1030263         1.684815e+18
# 3                  1030274         1.684722e+18
# 4                  1030288         1.684658e+18
# ...                    ...                  ...
# 29798  1683839551645814784                  NaN
# 29799  1683938283003183104                  NaN
# 29800  1683861079674195968                  NaN
# 29801  1683918306082955264                  NaN
# 29802  1683834001562140672                  NaN
#
#                                                     text            author_id  \
# 0      3 peaks Challenge #AxioActive💪\n\nOn the 12th ...   905089209446346752
# 1      Roche Drops Hemophilia A Candidate, Prepares f...             76385834
# 2      Roche moves one Spark hemophilia gene therapy ...  1481278019352338433
# ...

# %%
combined_df.isnull().sum()
# Out:
# tweet_id                      0
# external_twitter_id       14337
# text                          0
# author_id                     0
# created_at                    0
# lang                          0
# referenced_tweets_type        0
# referenced_tweets_id          0
# infos                         0
# association_tweet_id          0
# association_scope_id          0
# dtype: int64

# %%
df3 = pd.read_csv('/content/list_of_likes_by_tweet_id_050423.csv')
df3
# Out:
#     Unnamed: 0             tweet_id  \
# 0            0  1632975716743512066
# 1            1  1632259786216464384
# 2            2  1621748658461937668
# 3            3  1638052976718741507
# 4            4  1638778233221988353
# 5            5  1619199920568942592
# 6            6  1623924825730211841
# 7            7  1636968941544435717
# 8            8  1634794789496406016
# 9            9  1617034096471080961
# 10          10  1627911069711667201
# 11          11  1628263029447225344
# 12          12  1623200119439908864
# 13          13  1630446619685539842
# 14          14  1637331834190331904
# 15          15  1639143033081073664
# 16          16  1624286621008027648
# 17          17  1630807381490933765
# 18          18  1625736735648022528
# 19          19  1633699654629224449
# 20          20  1635521093174738946
# 21          21  1626456583952646152
# 22          22  1626822592119046145
#
#                                         list_of_likes      date_of_collect  \
# ...

# %%
df3.drop(['Unnamed: 0'], axis = 1, inplace = True)
df3.head()
# Out:
#               tweet_id                                      list_of_likes  \
# 0  1632975716743512066                                                 []
# 1  1632259786216464384                                                 []
# 2  1621748658461937668  [{'id': '2891104408', 'name': 'Courtney Thornb...
# 3  1638052976718741507                                                 []
# 4  1638778233221988353  [{'id': '324737377', 'name': 'Rob Fishbeck', '...
#
#        date_of_collect  count_likes
# 0  2023-04-05 17:25:37            0
# 1  2023-04-05 17:25:37            0
# 2  2023-04-05 17:25:37            3
# 3  2023-04-05 17:25:38            0
# 4  2023-04-05 17:25:38            5

# %%
common_tweetids = set(combined_df['tweet_id']).intersection(set(df3['tweet_id']))

if common_tweetids:
  print(f"Commontweetids found: {common_tweetids}")

else:
  print("No common tweetids found.")
# Out:
# Commontweetids found: {1632259786216464384, 1638778233221988353, 1632975716743512066, 1638052976718741507, 1621748658461937668, 1619199920568942592, 1623924825730211841, 1636968941544435717, 1634794789496406016, 1617034096471080961, 1627911069711667201, 1630446619685539842, 1630807381490933765, 1633699654629224449, 1635521093174738946, 1626456583952646152, 1623200119439908864, 1624286621008027648, 1626822592119046145, 1628263029447225344, 1637331834190331904, 1625736735648022528, 1639143033081073664}

# %%
combined_df1 = pd.merge(combined_df, df3, on = 'tweet_id', how = 'outer')
combined_df1
# Out:
#                   tweet_id  external_twitter_id  \
# 0                  1030258         1.684841e+18
# 1                  1030186         1.684592e+18
# 2                  1030263         1.684815e+18
# 3                  1030274         1.684722e+18
# 4                  1030288         1.684658e+18
# ...                    ...                  ...
# 29798  1683839551645814784                  NaN
# 29799  1683938283003183104                  NaN
# 29800  1683861079674195968                  NaN
# 29801  1683918306082955264                  NaN
# 29802  1683834001562140672                  NaN
#
#                                                     text            author_id  \
# 0      3 peaks Challenge #AxioActive💪\n\nOn the 12th ...   905089209446346752
# 1      Roche Drops Hemophilia A Candidate, Prepares f...             76385834
# 2      Roche moves one Spark hemophilia gene therapy ...  1481278019352338433
# ...

# %%
df4 = pd.read_csv("/content/authors_info_followers_050423.csv")
df4
# Out:
#     Unnamed: 0.1  Unnamed: 0            author_id  \
# 0              0           0  1529772772896956417
# 1              1           1            142801414
# 2              2           2             39823988
# 3              3           3  1638052926487756801
# 4              4           4             57557894
# 5              5           5  1252986246772559873
# 6              6           7            120400349
# 7              7           8   994242738676789249
# 8              8           9            138418838
# 9              9          10  1145266586015502336
# 10            10          11            132710839
# 11            11          13   843758096250036224
# 12            12           0  1595547432204410880
# 13            13           1  1407146606323900418
# 14            14           2  1530971264613072897
# 15            15           3  1476068819655270402
# 16            16           4  1602716642848690176
# 17            17           5  1176211661377683460
# ...

# %%
df4.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1, inplace=True)
df4
# Out:
#               author_id                                        author_info  \
# 0   1529772772896956417  {'id': '1529772772896956417', 'name': 'Cures',...
# 1             142801414  {'id': '142801414', 'name': 'NewWayHerbs.com',...
# 2              39823988  {'id': '39823988', 'name': 'National Hemophili...
# 3   1638052926487756801  {'id': '1638052926487756801', 'name': 'Judy Ho...
# 4              57557894  {'id': '57557894', 'name': 'Garth Harkness McM...
# 5   1252986246772559873  {'id': '1252986246772559873', 'name': 'ingenti...
# 6             120400349  {'id': '120400349', 'name': 'Javed Ahmad Tak',...
# 7    994242738676789249  {'id': '994242738676789249', 'name': 'World Ne...
# 8             138418838  {'id': '138418838', 'name': 'Stigmabase | ORG'...
# 9   1145266586015502336  {'id': '1145266586015502336', 'name': 'Infecte...
# 10            132710839  {'id': '132710839', 'name': 'Simon Fletcher', ...
# ...

# %%
df4['author_id'].nunique()
# Out:
# 20

# %%
# checking the common author_id's in earlier dataset and this new df4 dataset
common_authorid = set(combined_df1['author_id']).intersection(set(df4['author_id']))

if common_tweetids:
  print(f"Commonauthorids found: {common_authorid}")

else:
  print("No common authorid;s found.")
# Out:
# Commonauthorids found: {1145266586015502336, 1529772772896956417, 1252986246772559873, 994242738676789249, 1638052926487756801, 843758096250036224, 57557894, 142801414, 1595547432204410880, 1407146606323900418, 1530971264613072897, 1476068819655270402, 1176211661377683460, 138418838, 1602716642848690176, 32054188, 132710839, 120400349, 30846824, 39823988}

# %%
final_df = pd.merge(combined_df1,df4,on = 'author_id', how = 'outer')
final_df
# Out:
#                   tweet_id  external_twitter_id  \
# 0                  1030258         1.684841e+18
# 1                  1030642         1.687373e+18
# 2                  1030186         1.684592e+18
# 3                  1014927         1.663599e+18
# 4                   172076         1.630264e+18
# ...                    ...                  ...
# 29798  1620247498899230720                  NaN
# 29799               169778         1.621986e+18
# 29800  1621986081691279361                  NaN
# 29801               172062         1.630293e+18
# 29802  1630292933139202050                  NaN
#
#                                                     text            author_id  \
# 0      3 peaks Challenge #AxioActive💪\n\nOn the 12th ...   905089209446346752
# 1      3 peaks Challenge #AxioActive💪\n\nOn the 12th ...   905089209446346752
# 2      Roche Drops Hemophilia A Candidate, Prepares f...             76385834
# ...

# %%
final_df.isnull().sum()
# Out:
# tweet_id                      0
# external_twitter_id       14337
# text                          0
# author_id                     0
# created_at                    0
# lang                          0
# referenced_tweets_type        0
# referenced_tweets_id          0
# infos                         0
# association_tweet_id          0
# association_scope_id          0
# list_of_likes             29780
# date_of_collect_x         29780
# count_likes               29780
# author_info               28972
# list_of_followers         28972
# date_of_collect_y         28972
# count_followers           28972
# dtype: int64
