# %% [markdown]
# <a href="https://colab.research.google.com/github/nisha1365/Sanofi-POC/blob/main/author_info_Followers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/authors_info_followers_050423.csv")

# %%
df
# Out:
#     Unnamed: 0.1  Unnamed: 0            author_id  \
# 0              0           0  1529772772896956417
# 1              1           1            142801414
# 2              2           2             39823988
# 3              3           3  1638052926487756801
# 4              4           4             57557894
# 5              5           5  1252986246772559873
# 6              6           7            120400349
# 7              7           8   994242738676789249
# 8              8           9            138418838
# 9              9          10  1145266586015502336
# 10            10          11            132710839
# 11            11          13   843758096250036224
# 12            12           0  1595547432204410880
# 13            13           1  1407146606323900418
# 14            14           2  1530971264613072897
# 15            15           3  1476068819655270402
# 16            16           4  1602716642848690176
# 17            17           5  1176211661377683460
# ...

# %%
df.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1, inplace=True)
df.head()
# Out:
#              author_id                                        author_info  \
# 0  1529772772896956417  {'id': '1529772772896956417', 'name': 'Cures',...
# 1            142801414  {'id': '142801414', 'name': 'NewWayHerbs.com',...
# 2             39823988  {'id': '39823988', 'name': 'National Hemophili...
# 3  1638052926487756801  {'id': '1638052926487756801', 'name': 'Judy Ho...
# 4             57557894  {'id': '57557894', 'name': 'Garth Harkness McM...
#
#                                    list_of_followers      date_of_collect  \
# 0  [{'id': '1631787275284631553', 'name': 'Ceceli...  2023-04-05 13:21:44
# 1  [{'id': '4899374805', 'name': 'orpheus  james'...  2023-04-05 13:21:44
# 2  [{'id': '1643383029467869188', 'name': 'Sue Ma...  2023-04-05 13:27:41
# 3                                                 []  2023-04-05 13:27:41
# 4  [{'id': '1537335588583788544', 'name': 'Carol'...  2023-04-05 13:27:42
#
#    count_followers
# 0              438
# 1              978
# ...

# %%
cell_contents = df.at[12,'author_info']
#print the content of the cell
print("Contents of the 'author_info' cell:")
print(cell_contents)
# Out:
# Contents of the 'author_info' cell:
# {}

# %%
df.dtypes
# Out:
# author_id             int64
# author_info          object
# list_of_followers    object
# date_of_collect      object
# count_followers       int64
# dtype: object

# %%
import json

# %%
df['author_info'] = df['author_info'].astype(str)

# Extract 'id', 'name', and 'username' into separate columns
df['id'] = df['author_info'].str.extract(r"'id':\s*'(\d+)'", expand=False)
df['name'] = df['author_info'].str.extract(r"'name':\s*'([^']+)'", expand=False)
df['username'] = df['author_info'].str.extract(r"'username':\s*'([^']+)'", expand=False)

print(df)
# Out:
#               author_id                                        author_info  \
# 0   1529772772896956417  {'id': '1529772772896956417', 'name': 'Cures',...
# 1             142801414  {'id': '142801414', 'name': 'NewWayHerbs.com',...
# 2              39823988  {'id': '39823988', 'name': 'National Hemophili...
# 3   1638052926487756801  {'id': '1638052926487756801', 'name': 'Judy Ho...
# 4              57557894  {'id': '57557894', 'name': 'Garth Harkness McM...
# 5   1252986246772559873  {'id': '1252986246772559873', 'name': 'ingenti...
# 6             120400349  {'id': '120400349', 'name': 'Javed Ahmad Tak',...
# 7    994242738676789249  {'id': '994242738676789249', 'name': 'World Ne...
# 8             138418838  {'id': '138418838', 'name': 'Stigmabase | ORG'...
# 9   1145266586015502336  {'id': '1145266586015502336', 'name': 'Infecte...
# 10            132710839  {'id': '132710839', 'name': 'Simon Fletcher', ...
# ...

# %%
df.head()
# Out:
#              author_id                                        author_info  \
# 0  1529772772896956417  {'id': '1529772772896956417', 'name': 'Cures',...
# 1            142801414  {'id': '142801414', 'name': 'NewWayHerbs.com',...
# 2             39823988  {'id': '39823988', 'name': 'National Hemophili...
# 3  1638052926487756801  {'id': '1638052926487756801', 'name': 'Judy Ho...
# 4             57557894  {'id': '57557894', 'name': 'Garth Harkness McM...
#
#                                    list_of_followers      date_of_collect  \
# 0  [{'id': '1631787275284631553', 'name': 'Ceceli...  2023-04-05 13:21:44
# 1  [{'id': '4899374805', 'name': 'orpheus  james'...  2023-04-05 13:21:44
# 2  [{'id': '1643383029467869188', 'name': 'Sue Ma...  2023-04-05 13:27:41
# 3                                                 []  2023-04-05 13:27:41
# 4  [{'id': '1537335588583788544', 'name': 'Carol'...  2023-04-05 13:27:42
#
#    count_followers                   id                            name  \
# ...

# %%
new_df = df[['author_id', 'id','name','username']].copy()
new_df.to_csv('Author_id_info.csv', index = False)

# %%
cell_contents = df.at[8,'list_of_followers']
#print the content of the cell
print("Contents of the 'list_of_followers' cell:")
print(cell_contents)
# Out:
# Contents of the 'list_of_followers' cell:
# ...
