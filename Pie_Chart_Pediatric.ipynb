# %% [markdown]
# <a href="https://colab.research.google.com/github/nisha1365/GEN-AI-POC/blob/main/Pie_Chart_Pediatric.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
topics_list = pd.read_csv("/content/final_topics_name_120.csv")
topics_list
# Out:
#      Topic  Count                                              Name  \
# 0        0   5088                0_autism_vaccination_kid_mortality
# 1        1   2055                       1_measles_mmr_case_catching
# 2        2   2028                     2_covid_pregnant_risk_vaccine
# 3        3   1452                        3_tetanus_shot_hope_stitch
# 4        4    758                     4_rsv_pfizer_preterm_pregnant
# ..     ...    ...                                               ...
# 114    114     15            114_nasty_flusnotfunny_reception_spray
# 115    115     15       115_infertile_paternity_settling_widespread
# 116    116     15  116_corynebacterium_diphtheriae_tonsil_bacterial
# 117    117     15             117_hookworm_ringworm_worm_infections
# 118    118     15               118_cybertruck_buy_cybertrucks_lame
#
#                                         Representation  \
# 0    ['autism', 'vaccination', 'kid', 'mortality', ...
# 1    ['measles', 'mmr', 'case', 'catching', 'outbre...
# 2    ['covid', 'pregnant', 'risk', 'vaccine', 'vacc...
# 3    ['tetanus', 'shot', 'hope', 'stitch', 'wound',...
# 4    ['rsv', 'pfizer', 'preterm', 'pregnant', 'neon...
# ..                                                 ...
# 114  ['nasty', 'flusnotfunny', 'reception', 'spray'...
# 115  ['infertile', 'paternity', 'settling', 'widesp...
# 116  ['corynebacterium', 'diphtheriae', 'tonsil', '...
# 117  ['hookworm', 'ringworm', 'worm', 'infections',...
# 118  ['cybertruck', 'buy', 'cybertrucks', 'lame', '...
#
#                                    Representative_Docs  \
# 0    ['safest vaccine vaccine “ lockdown ” american...
# 1    ['3 million unvaccinated child risk catching m...
# 2    ['neonatal outcome covid-19 vaccination pregna...
# 3    ['get tetanus shot', 'would get tetanus shot',...
# 4    ['pfizer failed disclose risk preterm birth ne...
# ..                                                 ...
# 114  ['flu cause lot nasty symptom one want see chi...
# 115  ['careful `` woman new york started lying vacc...
# 116  ['diphtheria serious infection caused strain b...
# 117  ["'m joining war hookworm tetanus side hookwor...
# 118  ["'m thinking getting cybertruck . need update...
#
#                                             Topic_Name
# 0                          Vaccine Safety for Children
# 1                         MMR Vaccination for Children
# 2                Pediatric COVID-19 Vaccination Safety
# 3                                  Tetanus Vaccination
# 4    Pfizer's Failure to Disclose Risks of Preterm ...
# ..                                                 ...
# 114                Flu Vaccination for School Children
# 115                     COVID-19 Vaccine and Fertility
# 116                                         Diphtheria
# 117                              COVID-19 and Hookworm
# 118                 Tetanus Vaccination and Cybertruck
#
# [119 rows x 6 columns]

# %%
# !pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-2.3.1-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.37.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.1.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.4.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-2.3.1

# %%
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans
import numpy as np

# Load the SentenceTransformer model
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

# Embed the proper topic names
proper_topic_names = topics_list['Topic_Name'].tolist()
embeddings = model.encode(proper_topic_names)

# Convert embeddings to a 2D array
embeddings = np.array(embeddings)

# Add the embeddings as a new column in the dataframe
topics_list['embeddings'] = embeddings.tolist()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
topics_list
# Out:
#      Topic  Count                                              Name  \
# 0        0   5088                0_autism_vaccination_kid_mortality
# 1        1   2055                       1_measles_mmr_case_catching
# 2        2   2028                     2_covid_pregnant_risk_vaccine
# 3        3   1452                        3_tetanus_shot_hope_stitch
# 4        4    758                     4_rsv_pfizer_preterm_pregnant
# ..     ...    ...                                               ...
# 114    114     15            114_nasty_flusnotfunny_reception_spray
# 115    115     15       115_infertile_paternity_settling_widespread
# 116    116     15  116_corynebacterium_diphtheriae_tonsil_bacterial
# 117    117     15             117_hookworm_ringworm_worm_infections
# 118    118     15               118_cybertruck_buy_cybertrucks_lame
#
#                                         Representation  \
# 0    ['autism', 'vaccination', 'kid', 'mortality', ...
# 1    ['measles', 'mmr', 'case', 'catching', 'outbre...
# 2    ['covid', 'pregnant', 'risk', 'vaccine', 'vacc...
# 3    ['tetanus', 'shot', 'hope', 'stitch', 'wound',...
# 4    ['rsv', 'pfizer', 'preterm', 'pregnant', 'neon...
# ..                                                 ...
# 114  ['nasty', 'flusnotfunny', 'reception', 'spray'...
# 115  ['infertile', 'paternity', 'settling', 'widesp...
# 116  ['corynebacterium', 'diphtheriae', 'tonsil', '...
# 117  ['hookworm', 'ringworm', 'worm', 'infections',...
# 118  ['cybertruck', 'buy', 'cybertrucks', 'lame', '...
#
#                                    Representative_Docs  \
# 0    ['safest vaccine vaccine “ lockdown ” american...
# 1    ['3 million unvaccinated child risk catching m...
# 2    ['neonatal outcome covid-19 vaccination pregna...
# 3    ['get tetanus shot', 'would get tetanus shot',...
# 4    ['pfizer failed disclose risk preterm birth ne...
# ..                                                 ...
# 114  ['flu cause lot nasty symptom one want see chi...
# 115  ['careful `` woman new york started lying vacc...
# 116  ['diphtheria serious infection caused strain b...
# 117  ["'m joining war hookworm tetanus side hookwor...
# 118  ["'m thinking getting cybertruck . need update...
#
#                                             Topic_Name  \
# 0                          Vaccine Safety for Children
# 1                         MMR Vaccination for Children
# 2                Pediatric COVID-19 Vaccination Safety
# 3                                  Tetanus Vaccination
# 4    Pfizer's Failure to Disclose Risks of Preterm ...
# ..                                                 ...
# 114                Flu Vaccination for School Children
# 115                     COVID-19 Vaccine and Fertility
# 116                                         Diphtheria
# 117                              COVID-19 and Hookworm
# 118                 Tetanus Vaccination and Cybertruck
#
#                                             embeddings
# 0    [-0.044424887746572495, 0.68746018409729, -0.7...
# 1    [0.24038246273994446, 0.5673986077308655, -0.3...
# 2    [0.235974982380867, 0.39380332827568054, -0.64...
# 3    [-0.1904815286397934, 0.3540203869342804, -0.4...
# 4    [-0.12605537474155426, -0.04983966797590256, -...
# ..                                                 ...
# 114  [0.1935381293296814, 0.3088424801826477, -0.66...
# 115  [-0.038347627967596054, 0.5957480669021606, -0...
# 116  [0.1065187081694603, -0.33948206901550293, 0.3...
# 117  [-0.43184587359428406, -0.6488845348358154, -0...
# 118  [-0.030726388096809387, 0.04020185396075249, -...
#
# [119 rows x 7 columns]

# %%
# Extract the embeddings as a numpy array
embeddings = np.array(topics_list['embeddings'].tolist())

# Get the shape of the first embedding
embedding_shape = embeddings[0].shape

# Iterate through the embeddings and check if they all have the same shape
all_same_length = all(embedding.shape == embedding_shape for embedding in embeddings)

if all_same_length:
    print("All embeddings have the same length.")
else:
    print("Embeddings have different lengths.")
# Out:
# All embeddings have the same length.

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# Get the embeddings column as a numpy array
embeddings = np.array(topics_list['embeddings'].tolist())

# Define a range of possible cluster numbers to try
min_clusters = 2
max_clusters = 10
num_clusters_range = range(min_clusters, max_clusters+1)

# Initialize empty lists to store the results
inertias = []
silhouette_scores = []

# Loop over the range of possible cluster numbers
for k in num_clusters_range:
    # Train the K-Means model
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(embeddings)

    # Calculate the inertia and silhouette score
    inertia = kmeans.inertia_
    silhouette = silhouette_score(embeddings, kmeans.labels_)

    # Append the results to the lists
    inertias.append(inertia)
    silhouette_scores.append(silhouette)

# Plot the elbow curve to determine the optimal number of clusters
plt.plot(num_clusters_range, inertias, 'bx-')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow Curve')
plt.show()

# Plot the silhouette scores to determine the optimal number of clusters
plt.plot(num_clusters_range, silhouette_scores, 'bx-')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score')
plt.show()

# Determine the optimal number of clusters based on the elbow method
diffs = np.diff(inertias)
diffs_ratio = diffs[1:] / diffs[:-1]
k_elbow = num_clusters_range[np.argmax(diffs_ratio)+1]
print("Optimal number of clusters based on elbow method:", k_elbow)

# Determine the optimal number of clusters based on the silhouette score
k_silhouette = num_clusters_range[np.argmax(silhouette_scores)]
print("Optimal number of clusters based on silhouette score:", k_silhouette)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Optimal number of clusters based on elbow method: 9
# Optimal number of clusters based on silhouette score: 2

# %% [markdown]
# It is possible for the elbow method and silhouette score to give different optimal numbers of clusters. The elbow method is based on the sum of squared distances between data points and their cluster centers, while the silhouette score is based on the similarity of data points to their own cluster compared to other clusters.
#
# In some cases, the elbow method may suggest a higher number of clusters than the silhouette score because it is based on minimizing the sum of squared distances, which tends to favor more clusters. On the other hand, the silhouette score may suggest a lower number of clusters because it takes into account the similarity of data points to their own cluster compared to other clusters, which tends to favor fewer clusters.
#
# Ultimately, the optimal number of clusters depends on the specific dataset and the goals of the analysis. It is important to consider both the elbow method and silhouette score, as well as any other relevant factors, when determining the optimal number of clusters for a particular dataset.

# %%
# Extract the embeddings as a numpy array
embeddings = np.array(topics_list['embeddings'].tolist())

# Apply K-means clustering with 9 clusters
kmeans = KMeans(n_clusters=9, random_state=42)
cluster_labels = kmeans.fit_predict(embeddings)

# Update the cluster labels in the topics_list dataframe
topics_list['cluster_labels'] = cluster_labels
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
topics_list
# Out:
#      Topic  Count                                              Name  \
# 0        0   5088                0_autism_vaccination_kid_mortality
# 1        1   2055                       1_measles_mmr_case_catching
# 2        2   2028                     2_covid_pregnant_risk_vaccine
# 3        3   1452                        3_tetanus_shot_hope_stitch
# 4        4    758                     4_rsv_pfizer_preterm_pregnant
# ..     ...    ...                                               ...
# 114    114     15            114_nasty_flusnotfunny_reception_spray
# 115    115     15       115_infertile_paternity_settling_widespread
# 116    116     15  116_corynebacterium_diphtheriae_tonsil_bacterial
# 117    117     15             117_hookworm_ringworm_worm_infections
# 118    118     15               118_cybertruck_buy_cybertrucks_lame
#
#                                         Representation  \
# 0    ['autism', 'vaccination', 'kid', 'mortality', ...
# 1    ['measles', 'mmr', 'case', 'catching', 'outbre...
# 2    ['covid', 'pregnant', 'risk', 'vaccine', 'vacc...
# 3    ['tetanus', 'shot', 'hope', 'stitch', 'wound',...
# 4    ['rsv', 'pfizer', 'preterm', 'pregnant', 'neon...
# ..                                                 ...
# 114  ['nasty', 'flusnotfunny', 'reception', 'spray'...
# 115  ['infertile', 'paternity', 'settling', 'widesp...
# 116  ['corynebacterium', 'diphtheriae', 'tonsil', '...
# 117  ['hookworm', 'ringworm', 'worm', 'infections',...
# 118  ['cybertruck', 'buy', 'cybertrucks', 'lame', '...
#
#                                    Representative_Docs  \
# 0    ['safest vaccine vaccine “ lockdown ” american...
# 1    ['3 million unvaccinated child risk catching m...
# 2    ['neonatal outcome covid-19 vaccination pregna...
# 3    ['get tetanus shot', 'would get tetanus shot',...
# 4    ['pfizer failed disclose risk preterm birth ne...
# ..                                                 ...
# 114  ['flu cause lot nasty symptom one want see chi...
# 115  ['careful `` woman new york started lying vacc...
# 116  ['diphtheria serious infection caused strain b...
# 117  ["'m joining war hookworm tetanus side hookwor...
# 118  ["'m thinking getting cybertruck . need update...
#
#                                             Topic_Name  \
# 0                          Vaccine Safety for Children
# 1                         MMR Vaccination for Children
# 2                Pediatric COVID-19 Vaccination Safety
# 3                                  Tetanus Vaccination
# 4    Pfizer's Failure to Disclose Risks of Preterm ...
# ..                                                 ...
# 114                Flu Vaccination for School Children
# 115                     COVID-19 Vaccine and Fertility
# 116                                         Diphtheria
# 117                              COVID-19 and Hookworm
# 118                 Tetanus Vaccination and Cybertruck
#
#                                             embeddings  cluster_labels
# 0    [-0.044424887746572495, 0.68746018409729, -0.7...               0
# 1    [0.24038246273994446, 0.5673986077308655, -0.3...               5
# 2    [0.235974982380867, 0.39380332827568054, -0.64...               2
# 3    [-0.1904815286397934, 0.3540203869342804, -0.4...               4
# 4    [-0.12605537474155426, -0.04983966797590256, -...               1
# ..                                                 ...             ...
# 114  [0.1935381293296814, 0.3088424801826477, -0.66...               5
# 115  [-0.038347627967596054, 0.5957480669021606, -0...               2
# 116  [0.1065187081694603, -0.33948206901550293, 0.3...               6
# 117  [-0.43184587359428406, -0.6488845348358154, -0...               2
# 118  [-0.030726388096809387, 0.04020185396075249, -...               4
#
# [119 rows x 8 columns]

# %%
# Get the cluster counts
cluster_counts = topics_list['cluster_labels'].value_counts().sort_index()
cluster_counts
# Out:
# 0    11
# 1    12
# 2    34
# 3     7
# 4     5
# 5    21
# 6     3
# 7     9
# 8    17
# Name: cluster_labels, dtype: int64

# %%
import matplotlib.pyplot as plt

# Group the dataframe by cluster labels and count the occurrences of each proper topic name
cluster_counts = topics_list.groupby('cluster_labels')['Topic_Name'].value_counts()

# Plot a pie chart for each cluster
num_clusters = len(cluster_counts.index.levels[0])
fig, axs = plt.subplots(num_clusters, figsize=(6, 6 * num_clusters))
for i, (cluster_label, counts) in enumerate(cluster_counts.groupby(level=0)):
    axs[i].pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=140)
    axs[i].set_title(f'Cluster {cluster_label} - Proper Topic Name Distribution')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-13-cccf310ab389>:12: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
import plotly.express as px
# add cluster labels to dataframe
topics_list['cluster_labels'] = kmeans.labels_

# count number of topics in each cluster
cluster_counts =topics_list['cluster_labels'].value_counts().sort_index()

# create pie chart using Plotly
fig = px.pie(
    names=cluster_counts.index,
    values=cluster_counts.values,
    title="Cluster Distribution"
)

# show the pie chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d097ab40-73b1-4564-9930-f004b7727434" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d097ab40-73b1-4564-9930-f004b7727434")) {                    Plotly.newPlot(                        "d097ab40-73b1-4564-9930-f004b7727434",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":[0,1,2,3,4,5,6,7,8],"legendgroup":"","name":"","showlegend":true,"values":[11,12,34,7,5,21,3,9,17],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram" ...

# %%
# Create a dictionary of clusters and the topics in each cluster
cluster_dict = {}
for i in range(9):
    cluster_dict[i] = list(topics_list[topics_list['cluster_labels']==i]['Topic_Name'])

# Print the topics in each cluster
for i in range(9):
    print("Cluster {}:".format(i))
    for topic in cluster_dict[i]:
        print("- {}".format(topic))
# Out:
# Cluster 0:
# - Vaccine Safety for Children
# - Vaccines and SIDS
# - Vaccines and Autism
# - Vaccine Concerns
# - Vaccine Ingredients in Children's Vaccines
# - Vaccine Safety
# - Vaccine-Related Death of Pregnant Woman
# - Vaccine Safety Research
# - Vaccine Injuries
# - Vaccine Safety in Children
# - Vaccine Misinformation
# Cluster 1:
# - Pfizer's Failure to Disclose Risks of Preterm Birth and Neonatal Death in Pregnant Women in RSV Vaccine Trial
# - Topic Name: Immune response to mRNA SARS-CoV-2 vaccines in infants and pregnant women
# - Prenatal mRNA Vaccine Exposure and Autism-like Effects
# - Midwife Fined for Giving Homeopathic Pellets Instead of Vaccines
# - Maternal and Child Healthcare Programs
# - Serum Run to Nome
# - Routine Infant Circumcision
# - Financial Assistance for Baby's Health
# - Child Sex Trafficking
# - Newborn Vitamin K Injection
# - WEF Digital IDs
# - Formaldehyde in Infant Blood and Vaccines
# Cluster 2:
# - Pediatric COVID-19 Vaccination Safety
# - COVID-19 Vaccination for Children
# - COVID-19 Vaccine Mandates
# - Myocarditis after COVID-19 vaccination
# - COVID-19 Vaccination of Children in Brazil
# - COVID-19 Vaccination Recommendations
# - COVID-19 Vaccination for Children and Adolescents
# - COVID-19 Vaccination and Death Rates
# - Child COVID-19 Vaccination
# - Pediatric COVID-19 Vaccination Availability
# - COVID-19 Vaccine and Child Deaths
# - Pediatric Cardiologist Testimony on COVID Vaccines
# - COVID-19 Vaccination Safety in Children
# - COVID-19 Vaccination Recommendations
# - COVID Vaccine Side Effects in Infants
# - COVID-19 Vaccination Safety Signals in Children
# - COVID-19 Vaccination for Children in Ireland
# - Child Labor Law Changes Regarding COVID-19 Vaccination Requirements
# - Pediatric Heart Damage from COVID Vaccines
# - COVID-19 Vaccine Injury Compensation
# - COVID-19 Vaccination in Texas and Florida
# - Child COVID-19 Vaccination
# - Pediatric Dental Problems and COVID-19 Vaccination
# - COVID-19 Vaccine Boycott
# - COVID-19 Vaccination in Children Alters Cytokine Responses to Heterologous Pathogens
# - Free Flu and COVID-19 Vaccination for At-risk Groups
# - Child welfare during COVID-19 pandemic
# - Pediatric COVID-19 Vaccination Safety
# - COVID-19 Vaccine Misinformation
# - COVID-19 Misinformation
# - COVID-19 Vaccine Concerns
# - COVID Vaccination and Pregnant Women
# - COVID-19 Vaccine and Fertility
# - COVID-19 and Hookworm
# Cluster 3:
# - Routine Childhood Immunization
# - Child Pneumonia in Pakistan
# - Student Immunization Requirements
# - Child Deaths from Invasive Bacterial Infection
# - Pediatric Immunizations
# - Child Health Record Journal
# - Childhood Diseases
# Cluster 4:
# - Tetanus Vaccination
# - Tetanus from Rusty Nails
# - Vaccines for Rabies and Tetanus
# - Tetanus Infection
# - Tetanus Vaccination and Cybertruck
# Cluster 5:
# - MMR Vaccination for Children
# - Child Flu Vaccination
# - Pertussis Vaccination During Pregnancy
# - Child Vaccination in Gaza
# - UNICEF report on state of world's children and vaccination
# - Infant Deaths Following Vaccination
# - Pediatrician Experiences with Vaccines
# - Child Vaccination
# - Pediatric Vaccination Ethics
# - Childhood Vaccination
# - Vaccination of Children in Japan and the US
# - Vaccination Registry for Children in South Carolina
# - Childhood Vaccinations
# - Pregnancy Vaccination
# - Child Vaccination
# - Childhood Vaccination Safety
# - Child Vaccination Efforts in Kenya
# - Bill Gates and Child Vaccination
# - Child Vaccination in Gaza Strip
# - Child Vaccination Rights
# - Flu Vaccination for School Children
# Cluster 6:
# - Diphtheria Vaccination
# - Thimerosal Exposure and Brain Damage
# - Diphtheria
# Cluster 7:
# - Child Health Services in Tigray
# - Government Protest and Recovery of Funds
# - Amish and Autism
# - Helen Grus Police Misconduct Inquiry
# - Opisthotonus
# - Barefoot Walking and Tetanus Risk
# - Childhood's Deadly Scourge: Campaign to Control Diphtheria in New York City, 1880-1930
# - Newsroom Exposé
# - Democratic Party Conspiracy Theories
# Cluster 8:
# - Vaccination Against Preventable Diseases
# - Polio Vaccination Campaign in Afghanistan
# - Vaccination Recommendations
# - HPV Vaccination
# - Chickenpox Vaccination
# - Pneumonia Vaccination
# - Malaria Vaccination in Cameroon
# - Hepatitis B Vaccination
# - Anti-Polio Vaccination in North Waziristan
# - Measles-Rubella Vaccination
# - Mandatory Vaccination
# - Gulf War Illness and Vaccinations
# - Vaccination Scars
# - Cholera Vaccination
# - Anti-Vaccination Conspiracy Theories
# - Vaccination Conspiracy Theories
# - Yellow Fever Vaccination

# %% [markdown]
# ## Getting All Clusters in CSV

# %%
import pandas as pd

# Create a dictionary of clusters and the topics in each cluster
cluster_dict = {}
for i in range(9):
    cluster_dict[i] = list(topics_list[topics_list['cluster_labels']==i]['Topic_Name'])

# Find the length of the longest list
max_len = max(len(lst) for lst in cluster_dict.values())

# Add None values to the shorter lists to make them the same length
for i in range(9):
    while len(cluster_dict[i]) < max_len:
        cluster_dict[i].append(None)

# Create a DataFrame from the cluster dictionary
df = pd.DataFrame(cluster_dict)

# Save the DataFrame to a CSV file
df.to_csv('cluster_topics_Pediatric.csv', index=False)
